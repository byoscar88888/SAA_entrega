# %% [markdown]
# <a href="https://colab.research.google.com/github/byoscar88888/SAA_entrega/blob/main/T%C3%A9cnicas/Descenso%20del%20Gradiente/Descenso_del_Gradiente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función cuadrática
def f(x):
    return x**2 + 5

# Definir la derivada de la función cuadrática
def df(x):
    return 2*x

# Algoritmo de descenso del gradiente
def gradient_descent(learning_rate, iterations):
    x = np.random.uniform(-10, 10)  # Inicialización aleatoria de x
    history = [x]  # Historial de valores de x

    for _ in range(iterations):
        grad = df(x)  # Calcular el gradiente en el punto actual
        x = x - learning_rate * grad  # Actualizar el valor de x
        history.append(x)  # Agregar el nuevo valor de x al historial

    return x, history

learning_rate = 0.1
iterations = 50
optimal_x, history = gradient_descent(learning_rate, iterations)

# Imprimir el valor óptimo de x
print("Valor óptimo de x:", optimal_x)

# Graficar la función y el proceso de descenso del gradiente
x_values = np.linspace(-10, 10, 100)
plt.plot(x_values, f(x_values), label='Función cuadrática')
plt.scatter(history, f(np.array(history)), color='red', label='Descenso del gradiente')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Descenso del gradiente en una función cuadrática')
plt.legend()
plt.show()
# Out:
# Valor óptimo de x: 8.41537505526908e-05

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función
def f(x):
    return x**4 - 3*x**3 + 2

# Definir la derivada de la función
def df(x):
    return 4*x**3 - 9*x**2

# Algoritmo de descenso del gradiente
def gradient_descent(learning_rate, iterations):
    x = np.random.uniform(-2, 3)  # Inicialización aleatoria de x
    history = [x]  # Historial de valores de x

    for _ in range(iterations):
        grad = df(x)  # Calcular el gradiente en el punto actual
        x = x - learning_rate * grad  # Actualizar el valor de x
        history.append(x)  # Agregar el nuevo valor de x al historial

    return x, history

learning_rate = 0.01
iterations = 100
optimal_x, history = gradient_descent(learning_rate, iterations)

# Imprimir el valor óptimo de x
print("Valor óptimo de x:", optimal_x)

# Graficar la función y el proceso de descenso del gradiente
x_values = np.linspace(-2, 3, 100)
plt.plot(x_values, f(x_values), label='Función')
plt.scatter(history, f(np.array(history)), color='red', label='Descenso del gradiente')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Descenso del gradiente en una función arbitraria')
plt.legend()
plt.show()
# Out:
# Valor óptimo de x: 2.249999916084897
