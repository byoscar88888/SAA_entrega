# %% [markdown]
# <a href="https://colab.research.google.com/github/byoscar88888/SAA_entrega/blob/main/Aprendizaje%20Supervisado/Clasificacion/Regresion_Logistica/Regresi%C3%B3n_Log%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La regresión logística es un algoritmo de aprendizaje supervisado utilizado para problemas de clasificación binaria. Aunque su nombre incluye "regresión", se usa para clasificar, no para predecir valores continuos. Funciona modelando la relación entre las características de entrada y la probabilidad de que una observación pertenezca a una de dos clases.
#
# Utiliza una función sigmoide para transformar la salida en un valor entre 0 y 1, que se interpreta como la probabilidad de pertenecer a una clase. Luego, se asigna una etiqueta de clase basada en un umbral (generalmente 0.5).
#
# Es un algoritmo simple pero efectivo y se utiliza en una amplia gama de aplicaciones, como detección de spam, diagnóstico médico y análisis de riesgos financieros.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Datos de ejemplo
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 1, 1, 1])

# Crear y entrenar el modelo de regresión logística
model = LogisticRegression()
model.fit(X, y)

# Graficar los puntos de datos
plt.scatter(X, y, color='black')

# Graficar la línea de predicción
X_test = np.linspace(0, 6, 300).reshape(-1, 1)
y_prob = model.predict_proba(X_test)[:, 1]
plt.plot(X_test, y_prob, color='blue', linewidth=3)

# Hacer predicciones para nuevas muestras
nueva_muestra = np.array([[6]])
prediccion = model.predict(nueva_muestra)
plt.scatter(nueva_muestra, prediccion, color='red', marker='x', s=100)

plt.xlabel('Característica')
plt.ylabel('Etiqueta')
plt.title('Regresión Logística')
plt.legend(['Línea de predicción', 'Nuevas muestras'])
plt.show()

print("La predicción para la nueva muestra es:", prediccion[0])
# Out:
# La predicción para la nueva muestra es: 1

# %% [markdown]
# Este código en Google Colab utiliza la biblioteca NumPy para la manipulación de matrices y arreglos, Matplotlib para la visualización de datos y scikit-learn para implementar un modelo de regresión logística.
#
# Aquí está una explicación paso a paso del código:
#
# Se importan las bibliotecas necesarias:
#
# numpy como np para manejar matrices y arreglos numéricos.
# matplotlib.pyplot como plt para visualización.
# LogisticRegression de sklearn.linear_model para construir un modelo de regresión logística.
# Se definen datos de ejemplo X y y. X es una matriz 2D que contiene las características de entrada (en este caso, solo una característica por muestra), y y es un arreglo unidimensional que contiene las etiquetas correspondientes a esas características (0 o 1 en este caso).
#
# Se crea y entrena un modelo de regresión logística utilizando los datos de entrenamiento X e y.
#
# Se grafican los puntos de datos usando plt.scatter().
#
# Se generan puntos a lo largo de un rango específico (X_test) para predecir las probabilidades de clase utilizando model.predict_proba(). Estas probabilidades se usan para trazar la línea de predicción.
#
# Se hacen predicciones para una nueva muestra (nueva_muestra) utilizando model.predict() y se grafican usando plt.scatter().
#
# Se etiquetan los ejes y se agrega un título a la gráfica.
#
# Se muestra la leyenda y la gráfica utilizando plt.legend() y plt.show().
#
# Finalmente, se imprime la predicción para la nueva muestra.
#
# En resumen, el código crea un modelo de regresión logística para clasificar puntos de datos en dos clases (0 o 1). Luego, visualiza los datos de entrenamiento, la línea de predicción y realiza una predicción para una nueva muestra.
